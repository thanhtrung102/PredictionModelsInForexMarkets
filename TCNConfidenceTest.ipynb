# %%
from Scripts.utils import *  
import pandas as pd

columns = ['Date','Open','High','Low','Close','Volume','Yield','PercentageVolume',
           'SMA6','EMA6','WMA6','HMA6','SMA20','EMA20','WMA20','HMA20','SMA50','EMA50','WMA50','HMA50',
           'SMA100','EMA100','WMA100','HMA100','MACD','CCI','Stochastic Oscillator','RSI','ROC','PPO',
           'KST','BOLU','BOLD','BOLM']
data = pd.read_csv('/workspaces/PredictionModelsInForexMarkets/DataReady/EURUSD/EURUSD_D1.csv', names = columns, header = 0)

# %%
toRemove = ['Volume', 'Date','High','Low','Open','Close']
df = selectData(data,toRemove)

# %%
normDf = normalizeData(df)
images = generateImages(normDf)

# %%
close = np.array(data['Close'].reset_index(drop=True))[28:]
labels = np.zeros((len(close)-28,28), dtype=float)
print(labels.shape)
for i in range(len(close)-28):
    labels[i,:] = close[i:i+28]
labels.shape
# Out:
# (4159, 28)
# (4159, 28)

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(images[:-28], labels, test_size = 0.2,shuffle = True, random_state = 42)
train_X, valid_X, train_Y, valid_Y = train_test_split(train_X, train_Y, test_size = 0.1,shuffle = True, random_state = 42)

# %%
train_X = np.array([elem.reshape(28*28,1) for elem in train_X])
valid_X = np.array([elem.reshape(28*28,1) for elem in valid_X])
test_X = np.array([elem.reshape(28*28,1) for elem in test_X])

# %%
epochs_set = [30,70]
batches = [32]
learning_rates = [0.0005,0.001,0.01,0.1]
num_channels = [2,3,4,5,6]
nb_filters = [25,64,100]

# %%
combinations = []
for epochs in epochs_set:
    for batch_size in batches:
        for learning_rate in learning_rates:
            for num_channel in num_channels:
                for nb_filter in nb_filters:
                    combinations.append([epochs, batch_size,learning_rate, num_channel, nb_filter])

# %%
from Trials.TCNConfidence import *
preds = runLoadedModel(test_X, test_Y)
# Out:
# 2025-04-25 06:00:41.179473: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-25 06:00:41.185113: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-25 06:00:41.202463: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745560841.230121   40599 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745560841.238800   40599 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745560841.261975   40599 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745560841.262005   40599 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745560841.262008   40599 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745560841.262011   40599 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-25 06:00:41.268432: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 from Trials.TCNConfidence import *
# ----> 2 preds = runLoadedModel(test_X, test_Y)
#
# File /workspaces/PredictionModelsInForexMarkets/Trials/TCNConfidence.py:77, in runLoadedModel(test_X, test_Y)
#      75 loaded_model_json = json_file.read()
#      76 json_file.close()
# ---> 77 loaded_model = model_from_json(loaded_model_json)
#      78 # load weights into new model
#      79 loaded_model.load_weights('/workspaces/PredictionModelsInForexMarkets/Models/Trials/modelTCNconfidence.h5')
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/models/model.py:813, in model_from_json(json_string, custom_objects)
#     810 from keras.src.saving import serialization_lib
#     812 model_config = json.loads(json_string)
# --> 813 return serialization_lib.deserialize_keras_object(
#     814     model_config, custom_objects=custom_objects
#     815 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:694, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     691     if obj is not None:
#     692         return obj
# --> 694 cls = _retrieve_class_or_fn(
#     695     class_name,
#     696     registered_name,
#     697     module,
#     698     obj_type="class",
#     699     full_config=config,
#     700     custom_objects=custom_objects,
#     701 )
#     703 if isinstance(cls, types.FunctionType):
#     704     return cls
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:810, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     803         except ModuleNotFoundError:
#     804             raise TypeError(
#     805                 f"Could not deserialize {obj_type} '{name}' because "
#     806                 f"its parent module {module} cannot be imported. "
#     807                 f"Full object config: {full_config}"
#     808             )
# --> 810 raise TypeError(
#     811     f"Could not locate {obj_type} '{name}'. "
#     812     "Make sure custom classes are decorated with "
#     813     "`@keras.saving.register_keras_serializable()`. "
#     814     f"Full object config: {full_config}"
#     815 )
#
# TypeError: Could not locate class 'Functional'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'class_name': 'Functional', 'config': {'layers': [{'class_name': 'InputLayer', 'inbound_nodes': [], 'config': {'sparse': False, 'ragged': False, 'batch_input_shape': [None, 784, 1], 'dtype': 'float32', 'name': 'input_11'}, 'name': 'input_11'}, {'class_name': 'Conv1D', 'inbound_nodes': [[['input_11', 0, 0, {}]]], 'config': {'groups': 1, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'seed': 42, 'stddev': 0.01, 'mean': 0.0}}, 'padding': 'causal', 'bias_regularizer': None, 'use_bias': True, 'data_format': 'channels_last', 'filters': 64, 'dtype': 'float32', 'trainable': True, 'strides': [1], 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'activity_regularizer': None, 'kernel_constraint': None, 'dilation_rate': [1], 'kernel_size': [3], 'bias_constraint': None, 'name': 'conv1d_74', 'activation': 'linear', 'kernel_regularizer': None}, 'name': 'conv1d_74'}, {'class_name': 'BatchNormalization', 'inbound_nodes': [[['conv1d_74', 0, 0, {}]]], 'config': {'momentum': 0.99, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'axis': [2], 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_constraint': None, 'dtype': 'float32', 'epsilon': 0.001, 'trainable': True, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_constraint': None, 'name': 'batch_normalization_64', 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'gamma_regularizer': None, 'center': True, 'beta_regularizer': None, 'scale': True}, 'name': 'batch_normalization_64'}, {'class_name': 'Activation', 'inbound_nodes': [[['batch_normalization_64', 0, 0, {}]]], 'config': {'activation': 'relu', 'dtype': 'float32', 'trainable': True, 'name': 'activation_96'}, 'name': 'activation_96'}, {'class_name': 'Dropout', 'inbound_nodes': [[['activation_96', 0, 0, {}]]], 'config': {'noise_shape': None, 'rate': 0.2, 'name': 'dropout_64', 'seed': None, 'dtype': 'float32', 'trainable': True}, 'name': 'dropout_64'}, {'class_name': 'Conv1D', 'inbound_nodes': [[['dropout_64', 0, 0, {}]]], 'config': {'groups': 1, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'seed': 42, 'stddev': 0.01, 'mean': 0.0}}, 'padding': 'causal', 'bias_regularizer': None, 'use_bias': True, 'data_format': 'channels_last', 'filters': 64, 'dtype': 'float32', 'trainable': True, 'strides': [1], 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'activity_regularizer': None, 'kernel_constraint': None, 'dilation_rate': [1], 'kernel_size': [3], 'bias_constraint': None, 'name': 'conv1d_75', 'activation': 'linear', 'kernel_regularizer': None}, 'name': 'conv1d_75'}, {'class_name': 'BatchNormalization', 'inbound_nodes': [[['conv1d_75', 0, 0, {}]]], 'config': {'momentum': 0.99, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'axis': [2], 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_constraint': None, 'dtype': 'float32', 'epsilon': 0.001, 'trainable': True, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_constraint': None, 'name': 'batch_normalization_65', 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'gamma_regularizer': None, 'center': True, 'beta_regularizer': None, 'scale': True}, 'name': 'batch_normalization_65'}, {'class_name': 'Activation', 'inbound_nodes': [[['batch_normalization_65', 0, 0, {}]]], 'config': {'activation': 'relu', 'dtype': 'float32', 'trainable': True, 'name': 'activation_97'}, 'name': 'activation_97'}, {'class_name': 'Conv1D', 'inbound_nodes': [[['input_11', 0, 0, {}]]], 'config': {'groups': 1, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'seed': 42, 'stddev': 0.01, 'mean': 0.0}}, 'padding': 'same', 'bias_regularizer': None, 'use_bias': True, 'data_format': 'channels_last', 'filters': 64, 'dtype': 'float32', 'trainable': True, 'strides': [1], 'bias_init ...

# %%
from Scripts.TCN import *

mse_min = 0.0007076702716970458
corr_max = 0.0993168912282981

best_factor = np.sqrt(mse_min) * (1-corr_max)
for comb in combinations:
    best = False
    epochs, batch_size,learning_rate, num_channel, nb_filter = comb
    predictedPrices, mse, corr = run(train_X, valid_X, test_X, train_Y, valid_Y,test_Y,
                                    epochs, batch_size,learning_rate, num_channel, nb_filter, mse_min, corr_max)
    print("{},{}".format(mse,corr))
    if corr == corr and corr>0:
        factor = np.sqrt(mse)*(1-corr)
        if factor < best_factor:
            mse_min = mse
            corr_max = corr
            best_factor = factor
            best = True
            print("BEST")
    f = open('Results/resultsTCNConfidence.txt','a+')
    f.write("{},{},{},{},3,{},{},{}, {}\n".format(epochs,batch_size,num_channel,nb_filter,learning_rate,mse, corr, best))
    f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 10
#       8 best = False
#       9 epochs, batch_size,learning_rate, num_channel, nb_filter = comb
# ---> 10 predictedPrices, mse, corr = run(train_X, valid_X, test_X, train_Y, valid_Y,test_Y,
#      11                                 epochs, batch_size,learning_rate, num_channel, nb_filter, mse_min, corr_max)
#      12 print("{},{}".format(mse,corr))
#      13 if corr == corr and corr>0:
#
# TypeError: run() takes 12 positional arguments but 13 were given

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(images[:-28], labels, test_size = 0.2,shuffle = False)

# %%
train_X = np.array([elem.reshape(28*28,1) for elem in train_X])
test_X = np.array([elem.reshape(28*28,1) for elem in test_X])

# %%
from Scripts.TCN import *
predictedPrices = runLoadedModel(test_X, test_Y)

# %%
preds = np.zeros((predictedPrices.shape[0], predictedPrices.shape[0]+27))
for i in range(predictedPrices.shape[0]):
    preds[i,i:28+i] = predictedPrices[i,:]
predsMean = preds.sum(axis=1)/(preds != 0).sum(axis=1)
predsSigma = np.array([np.std([preds[i,j] for j in range(preds.shape[1]) if preds[i,j]!=0]) for i in range(preds.shape[0])])

# %%
future_test = np.array([elem.reshape(28*28,1) for elem in images[-28:]])
predictedPrices = runLoadedModel(future_test)

# %%
predsFuture = np.zeros((predictedPrices.shape[0], predictedPrices.shape[0]+27))
for i in range(predictedPrices.shape[0]):
    predsFuture[i,i:28+i] = predictedPrices[i,:]
predsMeanFuture = predsFuture.sum(axis=1)/(predsFuture != 0).sum(axis=1)
predsSigmaFuture = np.array([np.std([predsFuture[i,j] for j in range(predsFuture.shape[1]) if predsFuture[i,j]!=0]) for i in range(predsFuture.shape[0])])

# %%
predsSigmaFuture.shape

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=[30,10])
plt.grid()
plt.plot(range(len(predsMean)),predsMean, label = 'predictedTCN', color = 'darkorange', marker = '^')
plt.plot(range(len(test_Y[:,0])),test_Y[:,0], label = 'true', color = 'blue', marker = 'o')
plt.fill_between(range(len(predsMean)), 
                     predsMean + 2 * predsSigma, 
                     predsMean - 2 * predsSigma, 
                     alpha=0.5, label='Uncertainty')
plt.plot(range(len(predsMean), len(predsMean)+len(predsMeanFuture)),predsMeanFuture, label = 'Future', color = 'green', marker = '^')
plt.fill_between(range(len(predsMean), len(predsMean)+len(predsMeanFuture)), 
                     predsMeanFuture + 2 * predsSigmaFuture, 
                     predsMeanFuture - 2 * predsSigmaFuture, 
                     alpha=0.5, label='Uncertainty Future')
plt.legend()
plt.show()
